# %% [markdown]
# <a href="https://colab.research.google.com/github/maria2021831011/machine_learning/blob/main/5_1vector_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
plt.quiver(0,0,4,5)

# %%
plt.quiver(0,0,4,5,scale_units="xy",angles="xy",scale=1)
plt.xlim(-8, 8)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
plt.quiver(0,0,4,5,scale_units="xy",angles="xy",scale=1, color='b')
plt.quiver(0,0,-7,4,scale_units="xy",angles="xy",scale=1, color='r')
plt.xlim(-8, 8)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
vector_1=np.array([4,5])
vector_2=np.array([-7,4])
sum=vector_1+vector_2
print(sum)
# Out:
# [-3  9]

# %%
plt.quiver(0,0,4,5,scale_units="xy",angles="xy",scale=1, color='b')
plt.quiver(0,0,-7,4,scale_units="xy",angles="xy",scale=1, color='r')
plt.quiver(0,0,-3,9,scale_units="xy",angles="xy",scale=1, color='g')
plt.xlim(-8, 8)
plt.ylim(-8, 8)
# Out:
# (-8.0, 8.0)

# %% [markdown]
# substraction

# %%
import numpy as np
vector_1 = np.asarray([0,0,2,3])

vector_2 = np.asarray([0,0,3,-2])

difference = vector_1 - vector_2
print(difference)
# Out:
# [ 0  0 -1  5]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,3,-2, scale_units='xy', angles='xy', scale=1, color='y')
plt.quiver(0,0,-1,5, scale_units='xy', angles='xy', scale=1, color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = 2*vector_1

print(vector_2)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,4,6, scale_units='xy', angles='xy', scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = -0.5*vector_1

print(vector_2)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,-1,-1.5, scale_units='xy', angles='xy', scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
