# %% [markdown]
# <a href="https://colab.research.google.com/github/maria2021831011/machine_learning/blob/main/4_10_text_data_preprocessing_use_case_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
