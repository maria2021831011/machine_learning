# %% [markdown]
# <a href="https://colab.research.google.com/github/maria2021831011/machine_learning/blob/main/5_4_matrix_operation_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# creating two matrices

A = np.array([[2,3],[4,5]])

B = np.array([[6,7],[8,9]])

# %%
print(A)
# Out:
# [[2 3]
#  [4 5]]

# %%
print(B)
# Out:
# [[6 7]
#  [8 9]]

# %%
A.shape
# Out:
# (2, 2)

# %%
B.shape
# Out:
# (2, 2)

# %%
sum=A+B
print(sum)
# Out:
# [[ 8 10]
#  [12 14]]

# %%
# create two matrices with random values
matrix_1 = np.random.randint(10, size=(3,3))
matrix_2 = np.random.randint(20, size=(3,3))

# %%
print(matrix_1)
# Out:
# [[2 6 9]
#  [5 8 5]
#  [8 5 1]]

# %%
print(matrix_2)
# Out:
# [[2 9 7]
#  [9 7 5]
#  [8 2 7]]

# %%
sum = np.add(matrix_1, matrix_2)

# %%
print(sum)
# Out:
# [[ 4 15 16]
#  [14 15 10]
#  [16  7  8]]

# %%
# creating two matrices

A = np.array([[2,3],[4,5]])

B = np.array([[6,7],[8,9]])

# %%
difference = A - B

# %%
print(difference)
# Out:
# [[-4 -4]
#  [-4 -4]]

# %%
# create two matrices with random values
matrix_1 = np.random.randint(10, size=(3,3))
matrix_2 = np.random.randint(20, size=(3,3))
diff = np.subtract(matrix_1, matrix_2)


print(diff)
# Out:
# [[  4  -9   2]
#  [  5  -1  -6]
#  [  4  -8 -16]]

# %%
x = 5
y = np.random.randint(10, size=(4,4))

product = np.multiply(x,y)


print(product)
# Out:
# [[45 10 45 30]
#  [30 35  0 40]
#  [10 20 30  0]
#  [25 30 45 20]]

# %%
# create two matrices with random values
matrix_3 = np.random.randint(5, size=(3,3))
matrix_4 = np.random.randint(5, size=(3,4))

# %%
product = np.dot(matrix_3, matrix_4)

# %%
print(product)
# Out:
# [[ 3 12 15  3]
#  [ 9 15 10  8]
#  [17 19  8  8]]

# %%
product.shape
# Out:
# (3, 4)
